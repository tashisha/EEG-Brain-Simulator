# %%
# for X + Y coordinates

# X = Latitude, x range is +180 to -180
# Y = Longitude, y range is 1 to 210 annnddd 310 to 360 (block out 211 to 309)

# only increase Z 
# range for Z having a seizure
# range for z when not having a seizure
# what X + Y ranges would have the seizure

# Left temporal lobe range:
# X = -25 to -5
# Y = 50 to 120

# Right temporal lobe range:
# X = -25 to -5
# Y = -50 to -120


# normal brain Z 
#  0.5 to 0.1

# sezuire brain z
# 0.5 to 0.9


# {"AllData": [{"TimeStamp": "1", "Data": [-56.67300986, -0.5572313900000001, -23.46699353]}]}

import random
import json
import datetime

def generate_x_y_coordinates():
    
    return [330, 60, 0.08, 330, 70, 0.08, 340, 60, 0.08, 350, 70, 0.08, 340, 90, 0.08, 340, 70, 1, 350, 80, 1, 360, 90, 1, 1, 120, 1, 350, 120, 1, 340, 120, 1, 1, 110, 1, 1, 100, 1, 350, 110, 1, 350, 100, 1, 350, 90, 1, 340, 110, 1, 340, 80, 1, 340, 100, 0.08,
            1, 130, 1, 1, 140, 1, 1, 150, 1, 1, 160, 1, 1, 170, 1, 350, 130, 1, 340, 130, 1, 350, 140, 1, 350, 150, 1, 350, 160, 1, 350, 170, 1, 340, 140, 1, 340, 150, 1, 340, 160, 1, 340, 170, 1,
            10, 120, 1, 10, 130, 1, 10, 140, 1, 10, 150, 1, 10, 160, 1, 10, 170, 1, 20, 120, 1, 20, 130, 1, 20, 140, 1, 20, 150, 1, 20, 160, 1, 20, 170, 1, 30, 120, 1, 30, 130, 1, 30, 140, 1, 30, 150, 1, 30, 160, 1, 30, 170, 1, 40, 110, 1, 40, 120, 1, 40, 130, 1, 40, 140, 1, 40, 150, 1, 40, 160, 1, 40, 170, 0.08, 50, 110, 0.08, 50, 100, 0.08, 50, 90, 0.08, 50, 80, 0.08, 50, 70, 1, 50, 60, 1, 50, 50, 1, 50, 40, 1, 50, 30, 1, 50, 20, 1, 50, 10, 1, 60, 10, 1, 60, 20, 1, 60, 30, 1, 60, 40, 1, 60, 50, 1, 60, 60, 1, 60, 70, 1, 60, 80, 1, 60, 90, 1, 60, 100, 1, 60, 110, 1, 60, 120, 1, 70, 100, 0.08, 70, 90, 0.08, 70, 80, 1, 70, 70, 1, 70, 60, 1, 70, 50, 1, 70, 40, 1, 70, 30, 1, 70, 20, 1, 70, 10, 1, 80, 10, 1, 80, 40, 1, 80, 80, 1, 80, 100, 1, 80, 140, 1,
            50, 120, 1, 50, 130, 1, 50, 140, 1, 50, 150, 1, 50, 160, 1, 50, 170, 1, 60, 110, 1, 60, 120, 1, 60, 130, 1, 60, 140, 1, 60, 150, 1, 60, 160, 1, 60, 170, 1, 70, 110, 1, 70, 120, 1, 70, 130, 1, 70, 140, 1, 70, 150, 1, 70, 150, 1, 70, 160, 1, 70, 170, 1,
            10, 190, 1, 10, 200, 1, 10, 210, 1, 10, 220, 1, 10, 230, 1, 10, 240, 1, 10, 310, 1, 10, 320, 1, 10, 330, 1, 10, 340, 1, 10, 350, 1, 340, 200, 1, 340, 190, 1, 340, 210, 1, 340, 220, 1, 350, 190, 1, 350, 200, 1, 350, 210, 1, 350, 220, 1, 350, 230, 1, 350, 240, 1, 340, 240, 1,
            0, 190, 1, 0, 200, 1, 0, 210, 1, 0, 220, 1, 0, 230, 1, 0, 240, 1,0, 250, 0.08, 0, 260, 1, 0, 270, 1, 0, 280, 1, 350, 280, 1, 350, 270, 1, 350, 260, 1, 350, 250, 1, 340, 280, 1, 340, 270, 1, 340, 260, 1, 340, 250, 1, 340, 290, 1, 350, 290, 1, 350, 300, 1, 340, 300, 1, 330, 300, 1, 340, 310, 1, 330, 310, 1]

#     return list(nlist)

def generate_z(x, y, timestamp):
    '''
    # normal brain Z 
    #  0.5 to 0.1

    # seizure brain z
    # 0.5 to 0.9
    '''

    # NOTE: HERE IS WHERE YOU DEFINE
    # MIN AND MAX RANGES FOR
    # SEIZURE OR NO SEIZURE
    #seizure_min_range = 0.07 #Tier 1
    #seizure_max_range = 0.12 # Tier 1
    
    seizure_min_range = 0.06 #Tier 2
    seizure_max_range = 0.11 # Tier 2
    
    #seizure_min_range = 0.05 #Tier 3
    #seizure_max_range = 0.10 # Tier 3
    
    non_seizure_min_range = 0.05
    non_seizure_max_range = 0.09
    
    
    # NOTE: HERE IS WHERE YOU ADD SEIZURE TYPE
    #seizure_type = "none"
    seizure_type = "right"
    #seizure_type = "left"
    #seizure_type = "random"
    #seizure_type = "Lrand"
    #seizure_type = "Rrand"
    #seizure_type = "OtherLrand"
    
    x_y = (x, y)
    
    if seizure_type == "none":
        return random.uniform(non_seizure_min_range, non_seizure_max_range)
    
    if seizure_type == "random":
        return random.uniform(non_seizure_min_range, seizure_max_range)
    
    
    if seizure_type == "left":
        targetted_area = [(330, 60), (330,70), (340,60), (350,70), (340,90), (340, 70),
                            (350, 80), (360, 90), (1, 120), (350, 120), (340,120), (1,110),
                            (1,100), (350,110), (350,100), (350,90), (340,110), (340,80), (340,100)]
        
    if seizure_type == "right":
        targetted_area = [(0,250), (0,260), (0,270), (0,280), (350,280), (350,270),
                               (350,260), (350,250), (340,280), (340,270), (340,260),
                               (340,250), (340,290), (350,290), (350,300), (340,300),
                               (330,300), (340,310), (330,310)]
        
    if seizure_type == "Lrand":
        targetted_area = [(320, 50), (330, 60), (340, 70), (350, 80), (360, 90), (1, 120), (350, 120), (340,120), (1,110),
                         (1,100,), (350,110), (350,100), (350,90), (340,110), (340,80), (340,100),
                            (1, 130), (1, 140), (1,150), (10,120), (10, 130), (10,140),  (10,150),  (10,160),  (10,170),  (20,120),  (20,130), 
                            (20,140),  (20,150),  (20,160),  (20,170), (30,120),  (30,130),  (30,140), 
                            (30,150), (30,160), (30,170),  (40,110),  (40,120), (40,130),  (40,140),
                            (40,150)]
            
    if seizure_type == "Rrand":
            targetted_area = [(40, 190), (40, 200), (40, 210), (40, 220), (40, 230), (40, 240), (40, 250), 
                                (40,260), (40, 270), (40, 280), (40, 290), (40, 300), (40, 310), (40, 320), (40, 330),
                                (40, 340), (40, 350), (30, 190), (30, 200), (30, 210), (30, 220), (30, 230),
                                (30, 250), (30, 260), (30, 270), (30, 280)]
        
    # not a seizure in timestamp 0 or 1
    if (timestamp in [0,1,2]):
        z = random.uniform(non_seizure_min_range, non_seizure_max_range)
        return z
    # Left temporal lobe range
    elif (x_y in targetted_area):
        z = random.uniform(seizure_min_range, seizure_max_range)
#         print("seizure data")
#         print("{}, {}, {}".format(x, y, z))
        return z
    # else it's not a seizure point
    else:
#         print("regular point")
        z = random.uniform(non_seizure_min_range, non_seizure_max_range) 
        return z

def generate_data(timestamp):
    data = []
    x_y_coordinates = generate_x_y_coordinates()
    count = 0
    
    for data_point in x_y_coordinates:
        count = count + 1
        if (count % 3 == 0):
            x_y_coordinates[count - 1] = generate_z(x_y_coordinates[count - 3], x_y_coordinates[count - 2], timestamp)

    return x_y_coordinates


all_data = []

for timestamp in range(10):
    # add timestamp details
    timestamp_object = {}
    timestamp_object["TimeStamp"] = str(timestamp)
    # print("timestamp object {}".format(timestamp_object))
    all_data.append(timestamp_object)
    
    # add data
    timestamp_data = generate_data(timestamp)
    timestamp_object["Data"] = timestamp_data

final_all_data_dict = {}   
final_all_data_dict["AllData"] = all_data

print(final_all_data_dict)

json_name = 'simulated_braincoordinates_{}.json'.format(datetime.datetime.now().time())

with open(json_name, 'w') as json_file:
  json.dump(final_all_data_dict, json_file)
# Out:
# {'AllData': [{'TimeStamp': '0', 'Data': [330, 60, 0.08663473475494468, 330, 70, 0.0809365548306072, 340, 60, 0.08334985487182069, 350, 70, 0.054557337342011104, 340, 90, 0.06634838963062277, 340, 70, 0.06979274444748457, 350, 80, 0.05047394662765757, 360, 90, 0.08342422346268498, 1, 120, 0.07845474399974069, 350, 120, 0.07406201120136063, 340, 120, 0.07341956220756489, 1, 110, 0.07619725845204434, 1, 100, 0.06534264638270268, 350, 110, 0.07499669671553116, 350, 100, 0.06078067740408827, 350, 90, 0.07916051580512003, 340, 110, 0.06882843464532065, 340, 80, 0.05171534746057149, 340, 100, 0.06133706546774682, 1, 130, 0.07105240656086267, 1, 140, 0.08684592221298987, 1, 150, 0.0856430992133354, 1, 160, 0.0828377093326808, 1, 170, 0.0787342683511568, 350, 130, 0.08469181682807722, 340, 130, 0.08939263325881754, 350, 140, 0.0859712403886978, 350, 150, 0.08045948822595281, 350, 160, 0.08323796226610605, 350, 170, 0.08001252868394816, 340, 140, 0.05011157932598287, 340, 150, 0.07640097032531
# ...
